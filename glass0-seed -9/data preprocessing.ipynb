# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import DataFrame

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('../data/glass0.dat')

# %%
df.columns
# Out:
# Index(['RI', ' Na', ' Mg', ' Al', ' Si', ' K', ' Ca', ' Ba', ' Fe', 'Outcome'], dtype='object')

# %%
# %matplotlib inline
sns.countplot(x='Outcome',data=df)

# %%
df_min=df[df['Outcome']==' positive']

# %%
df_majority=df[df['Outcome']==' negative']

# %%
df_min.to_csv('glass0_minority.csv',index=False)
df_majority.to_csv('glass0_majority.csv',index=False)

# %%
data=np.array(df.values)

pos=data.shape[1]-1

for i in range(data.shape[0]):
    if data[i][pos]==' negative':
        data[i][pos]=0
    else:
        data[i][pos]=1


min_data=np.array(df_min)
maj_data=np.array(df_majority)

# %%
validation=0.30
seed=9

# %%
data.shape
# Out:
# (214, 10)

# %%
df_min.shape
# Out:
# (70, 10)

# %%
min_data.shape
# Out:
# (70, 10)

# %%
maj_data.shape
# Out:
# (144, 10)

# %%
X=data[:,:9].astype(float)# getting the feature values
Y=data[:,9]# getting prediction

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=validation,random_state=seed)

# %%
X_train.shape
# Out:
# (149, 9)

# %%
Y_train=Y_train.reshape((Y_train.shape[0],1))

# %%
Y_train.shape
# Out:
# (149, 1)

# %%
train_Data=np.concatenate((X_train,Y_train),axis=1)

# %%
train_Data[:10]
# Out:
# array([[1.51846238, 13.40995, 3.8883400000000004, 1.33004, 72.3804,
#         0.50922, 8.2814, 0.0, 0.0, 0],
#        [1.51818902, 13.7225, 0.0, 0.5596399999999999, 74.4524, 0.0,
#         10.99292, 0.0, 0.0, 0],
#        [1.5177562, 13.52965, 3.4079099999999998, 1.5194299999999998,
#         72.0388, 0.57753, 8.78712, 0.0, 0.0, 0],
#        [1.51837126, 14.321, 3.2597400000000003, 2.21921, 71.2492,
#         1.45935, 5.785080000000001, 1.62855, 0.0, 0],
#        [1.51905466, 14.0018, 2.38868, 1.56116, 72.3692, 0.0, 9.5726, 0.0,
#         0.0, 0],
#        [1.51828014, 13.23705, 3.90181, 1.41029, 72.33, 0.55269, 8.31368,
#         0.0, 0.051, 0],
#        [1.51654886, 12.7516, 2.85115, 1.43918, 73.2708,
#         0.5713199999999999, 8.78712, 0.11025, 0.1122, 0],
#        [1.5219705, 14.3609, 3.8479300000000003, 0.8902700000000001,
#         71.3612, 0.14904, 9.15296, 0.0, 0.0, 1],
#        [1.51777898, 13.21045, 2.81074, 1.29152, 72.9796, 0.50922,
#         9.02384, 0.0, 0.45899999999999996, 1],
#        [1.51709558, 12.99765, 3.47077, 1.7890700000000002, 72.722,
#         0.6582600000000001, 8.184560000000001, 0.0, 0.0, 0]], dtype=object)

# %%
Y_test=Y_test.reshape((Y_test.shape[0],1))

# %%
test_Data=np.concatenate((X_test,Y_test),axis=1)

# %%
train_Data=DataFrame(train_Data)
test_Data=DataFrame(test_Data)

# %%
# %matplotlib inline
sns.countplot(x=9,data=train_Data)

# %%
# %matplotlib inline
sns.countplot(x=9,data