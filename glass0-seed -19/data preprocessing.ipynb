# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import DataFrame

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('../data/glass0.dat')

# %%
df.columns
# Out:
# Index(['RI', ' Na', ' Mg', ' Al', ' Si', ' K', ' Ca', ' Ba', ' Fe', 'Outcome'], dtype='object')

# %%
# %matplotlib inline
sns.countplot(x='Outcome',data=df)

# %%
df_min=df[df['Outcome']==' positive']

# %%
df_majority=df[df['Outcome']==' negative']

# %%
df_min.to_csv('glass0_minority.csv',index=False)
df_majority.to_csv('glass0_majority.csv',index=False)

# %%
data=np.array(df.values)

pos=data.shape[1]-1

for i in range(data.shape[0]):
    if data[i][pos]==' negative':
        data[i][pos]=0
    else:
        data[i][pos]=1


min_data=np.array(df_min)
maj_data=np.array(df_majority)

# %%
validation=0.30
seed=19

# %%
data.shape
# Out:
# (214, 10)

# %%
df_min.shape
# Out:
# (70, 10)

# %%
min_data.shape
# Out:
# (70, 10)

# %%
maj_data.shape
# Out:
# (144, 10)

# %%
X=data[:,:9].astype(float)# getting the feature values
Y=data[:,9]# getting prediction

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=validation,random_state=seed)

# %%
X_train.shape
# Out:
# (149, 9)

# %%
Y_train=Y_train.reshape((Y_train.shape[0],1))

# %%
Y_train.shape
# Out:
# (149, 1)

# %%
train_Data=np.concatenate((X_train,Y_train),axis=1)

# %%
train_Data[:10]
# Out:
# array([[1.51509094, 15.15225, 0.0, 2.2513099999999997, 73.5004, 0.0,
#         8.3352, 0.63, 0.0, 0],
#        [1.5165033, 14.38085, 0.0, 1.9399400000000002, 73.6124, 0.0,
#         8.47508, 1.5687, 0.0, 0],
#        [1.51768786, 12.65185, 3.56057, 1.30115, 73.0804, 0.60858,
#         8.69028, 0.0, 0.0714, 1],
#        [1.51768786, 12.45235, 2.71196, 1.29152, 73.702, 0.5589, 9.05612,
#         0.0, 0.1224, 1],
#        [1.5151364999999999, 14.00845, 2.68053, 3.5, 69.8884, 1.68291,
#         5.87116, 2.1987, 0.0, 0],
#        [1.51657164, 14.7998, 0.0, 1.9913, 73.1084, 0.0, 8.2814, 1.71045,
#         0.0, 0],
#        [1.51871296, 12.93115, 3.65935, 1.56116, 72.5092, 0.57753, 8.5504,
#         0.0, 0.0612, 0],
#        [1.52171992, 13.5097, 3.8614, 0.88064, 71.7924,
#         0.22976999999999997, 9.54032, 0.0, 0.0561, 1],
#        [1.52365622, 15.79065, 1.83192, 1.3107799999999998, 70.4316,
#         0.3105, 8.61496, 1.67895, 0.0, 0],
#        [1.5177562, 12.85135, 3.47975, 1.23053, 72.9684, 0.60858,
#         8.561160000000001, 0.09135, 0.1122, 1]], dtype=object)

# %%
Y_test=Y_test.reshape((Y_test.shape[0],1))

# %%
test_Data=np.concatenate((X_test,Y_test),axis=1)

# %%
train_Data=DataFrame(train_Data)
test_Data=DataFrame(test_Data)

# %%
# %matplotlib inline
sns.countplot(x=9,data=train_Data)

# %%
# %matplotlib inline
sns.countplot(x=9,data