# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import DataFrame

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('../data/glass1.dat')

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Outcome'], dtype='object')

# %%
# %matplotlib inline
sns.countplot(x='Outcome',data=df)

# %%
df_min=df[df['Outcome']==' positive']

# %%
df_majority=df[df['Outcome']==' negative']

# %%
df_min.to_csv('glass1_minority.csv',index=False)
df_majority.to_csv('glass1_majority.csv',index=False)

# %%
data=np.array(df.values)

pos=data.shape[1]-1

for i in range(data.shape[0]):
    if data[i][pos]==' negative':
        data[i][pos]=0
    else:
        data[i][pos]=1


min_data=np.array(df_min)
maj_data=np.array(df_majority)

# %%
validation=0.30
seed=5

# %%
data.shape
# Out:
# (214, 10)

# %%
df_min.shape
# Out:
# (76, 10)

# %%
min_data.shape
# Out:
# (76, 10)

# %%
maj_data.shape
# Out:
# (138, 10)

# %%
X=data[:,:9].astype(float)# getting the feature values
Y=data[:,9]# getting prediction

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=validation,random_state=seed)

# %%
X_train.shape
# Out:
# (149, 9)

# %%
Y_train=Y_train.reshape((Y_train.shape[0],1))

# %%
Y_train.shape
# Out:
# (149, 1)

# %%
train_Data=np.concatenate((X_train,Y_train),axis=1)

# %%
train_Data[:10]
# Out:
# array([[1.51853072, 14.08825, 2.19112, 1.66067, 72.6716, 0.0, 9.32512,
#         0.0, 0.0, 0],
#        [1.5229956, 13.3102, 3.57853, 0.81965, 71.9884,
#         0.11799000000000001, 10.17516, 0.0, 0.0153, 0],
#        [1.51905466, 13.6028, 3.6189400000000003, 1.10855, 72.638,
#         0.14282999999999998, 8.75484, 0.0, 0.0, 0],
#        [1.51622994, 14.2013, 0.0, 2.7905900000000003, 73.4612, 0.03726,
#         9.04536, 0.40005, 0.45899999999999996, 0],
#        [1.5163893999999998, 14.36755, 0.0, 2.73923, 72.8508, 0.0,
#         9.454239999999999, 0.53865, 0.0, 0],
#        [1.52613924, 13.70255, 0.0, 1.35893, 71.238, 0.19251, 13.43544,
#         0.0, 0.051, 1],
#        [1.51768786, 12.65185, 3.56057, 1.30115, 73.0804, 0.60858,
#         8.69028, 0.0, 0.0714, 0],
#        [1.51689056, 13.33015, 3.5381199999999997, 1.60931, 72.5428,
#         0.6831, 8.10924, 0.0, 0.0, 1],
#        [1.51761952, 13.88875, 3.6009800000000003, 1.35893, 72.7276,
#         0.47817, 7.82948, 0.0, 0.0, 0],
#        [1.51818902, 13.7225, 0.0, 0.5596399999999999, 74.4524, 0.0,
#         10.99292, 0.0, 0.0, 1]], dtype=object)

# %%
Y_test=Y_test.reshape((Y_test.shape[0],1))

# %%
test_Data=np.concatenate((X_test,Y_test),axis=1)

# %%
train_Data=DataFrame(train_Data)
test_Data=DataFrame(test_Data)

# %%
# %matplotlib inline
sns.countplot(x=9,data